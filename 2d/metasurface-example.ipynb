# %%
import matplotlib.pyplot as plt
import numpy as np

import meep as mp

resolution = 50  # pixels/μm

dpml = 1.0  # PML thickness
dsub = 3.0  # substrate thickness
dpad = 3.0  # padding between grating and PML

lcen = 0.5  # center wavelength
fcen = 1 / lcen  # center frequency
df = 0.2 * fcen  # frequency width

focal_length = 200  # focal length of metalens
spot_length = 100  # far field line length
ff_res = 10  # far field resolution (points/μm)

k_point = mp.Vector3(0, 0, 0)

glass = mp.Medium(index=1.5)

pml_layers = [mp.PML(thickness=dpml, direction=mp.X)]

symmetries = [mp.Mirror(mp.Y)]


def grating(gp, gh, gdc_list):
    sx = dpml + dsub + gh + dpad + dpml
    src_pt = mp.Vector3(-0.5 * sx + dpml + 0.5 * dsub)
    mon_pt = mp.Vector3(0.5 * sx - dpml - 0.5 * dpad)
    geometry = [
        mp.Block(
            material=glass,
            size=mp.Vector3(dpml + dsub, mp.inf, mp.inf),
            center=mp.Vector3(-0.5 * sx + 0.5 * (dpml + dsub)),
        )
    ]

    num_cells = len(gdc_list)
    if num_cells == 1:
        sy = gp
        cell_size = mp.Vector3(sx, sy, 0)

        sources = [
            mp.Source(
                mp.GaussianSource(fcen, fwidth=df),
                component=mp.Ez,
                center=src_pt,
                size=mp.Vector3(y=sy),
            )
        ]

        sim = mp.Simulation(
            resolution=resolution,
            cell_size=cell_size,
            boundary_layers=pml_layers,
            k_point=k_point,
            default_material=glass,
            sources=sources,
            symmetries=symmetries,
        )

        flux_obj = sim.add_flux(
            fcen, 0, 1, mp.FluxRegion(center=mon_pt, size=mp.Vector3(y=sy))
        )

        sim.run(until_after_sources=50)

        input_flux = mp.get_fluxes(flux_obj)

        sim.reset_meep()

        geometry.append(
            mp.Block(
                material=glass,
                size=mp.Vector3(gh, gdc_list[0] * gp, mp.inf),
                center=mp.Vector3(-0.5 * sx + dpml + dsub + 0.5 * gh),
            )
        )

        sim = mp.Simulation(
            resolution=resolution,
            cell_size=cell_size,
            boundary_layers=pml_layers,
            geometry=geometry,
            k_point=k_point,
            sources=sources,
            symmetries=symmetries,
        )

        flux_obj = sim.add_flux(
            fcen, 0, 1, mp.FluxRegion(center=mon_pt, size=mp.Vector3(y=sy))
        )

        sim.run(until_after_sources=200)

        freqs = mp.get_eigenmode_freqs(flux_obj)
        res = sim.get_eigenmode_coefficients(
            flux_obj, [1], eig_parity=mp.ODD_Z + mp.EVEN_Y
        )
        coeffs = res.alpha

        mode_tran = abs(coeffs[0, 0, 0]) ** 2 / input_flux[0]
        mode_phase = np.angle(coeffs[0, 0, 0])
        if mode_phase > 0:
            mode_phase -= 2 * np.pi

        return mode_tran, mode_phase

    else:
        sy = num_cells * gp
        cell_size = mp.Vector3(sx, sy, 0)

        sources = [
            mp.Source(
                mp.GaussianSource(fcen, fwidth=df),
                component=mp.Ez,
                center=src_pt,
                size=mp.Vector3(y=sy),
            )
        ]

        geometry.extend(
            mp.Block(
                material=glass,
                size=mp.Vector3(gh, gdc_list[j] * gp, mp.inf),
                center=mp.Vector3(
                    -0.5 * sx + dpml + dsub + 0.5 * gh, -0.5 * sy + (j + 0.5) * gp
                ),
            )
            for j in range(num_cells)
        )
        sim = mp.Simulation(
            resolution=resolution,
            cell_size=cell_size,
            boundary_layers=pml_layers,
            geometry=geometry,
            k_point=k_point,
            sources=sources,
            symmetries=symmetries,
        )

        n2f_obj = sim.add_near2far(
            fcen, 0, 1, mp.Near2FarRegion(center=mon_pt, size=mp.Vector3(y=sy))
        )

        sim.run(until_after_sources=500)

        return (
            abs(
                sim.get_farfields(
                    n2f_obj,
                    ff_res,
                    center=mp.Vector3(-0.5 * sx + dpml + dsub + gh + focal_length),
                    size=mp.Vector3(spot_length),
                )["Ez"]
            )
            ** 2
        )


gp = 0.3  # grating periodicity
gh = 1.8  # grating height
gdc = np.linspace(0.1, 0.9, 30)  # grating duty cycle

mode_tran = np.empty(gdc.size)
mode_phase = np.empty(gdc.size)
for n in range(gdc.size):
    mode_tran[n], mode_phase[n] = grating(gp, gh, [gdc[n]])

plt.figure(dpi=200)
plt.subplot(1, 2, 1)
plt.plot(gdc, mode_tran, "bo-")
plt.xlim(gdc[0], gdc[-1])
plt.xticks(list(np.linspace(0.1, 0.9, 5)))
plt.xlabel("grating duty cycle")
plt.ylim(0.96, 1.00)
plt.yticks(list(np.linspace(0.96, 1.00, 5)))
plt.title("transmittance")

plt.subplot(1, 2, 2)
plt.plot(gdc, mode_phase, "rs-")
plt.grid(True)
plt.xlim(gdc[0], gdc[-1])
plt.xticks(list(np.linspace(0.1, 0.9, 5)))
plt.xlabel("grating duty cycle")
plt.ylim(-2 * np.pi, 0)
plt.yticks(list(np.linspace(-6, 0, 7)))
plt.title("phase (radians)")

plt.tight_layout(pad=0.5)
plt.show()

gdc_new = np.linspace(0.16, 0.65, 500)
mode_phase_interp = np.interp(gdc_new, gdc, mode_phase)
print(f"phase-range:, {mode_phase_interp.max() - mode_phase_interp.min():.6f}")

phase_tol = 1e-2
num_cells = [100, 200, 400]
ff_nc = np.empty((spot_length * ff_res, len(num_cells)))

for k in range(len(num_cells)):
    gdc_list = []
    for j in range(-num_cells[k], num_cells[k] + 1):
        phase_local = (
            2
            * np.pi
            / lcen
            * (focal_length - ((j * gp) ** 2 + focal_length**2) ** 0.5)
        )  # local phase at the center of the j'th unit cell
        phase_mod = phase_local % (-2 * np.pi)  # restrict phase to [-2*pi,0]
        if phase_mod > mode_phase_interp.max():
            phase_mod = mode_phase_interp.max()
        if phase_mod < mode_phase_interp.min():
            phase_mod = mode_phase_interp.min()
        idx = np.transpose(
            np.nonzero(
                np.logical_and(
                    mode_phase_interp > phase_mod - phase_tol,
                    mode_phase_interp < phase_mod + phase_tol,
                )
            )
        )
        gdc_list.append(gdc_new[idx[0][0]])

    ff_nc[:, k] = grating(gp, gh, gdc_list)

x = np.linspace(
    focal_length - 0.5 * spot_length,
    focal_length + 0.5 * spot_length,
    ff_res * spot_length,
)
plt.figure(dpi=200)
plt.semilogy(x, abs(ff_nc[:, 0]) ** 2, "bo-", label=f"num_cells = {2*num_cells[0] + 1}")
plt.semilogy(x, abs(ff_nc[:, 1]) ** 2, "ro-", label=f"num_cells = {2*num_cells[1] + 1}")
plt.semilogy(x, abs(ff_nc[:, 2]) ** 2, "go-", label=f"num_cells = {2*num_cells[2] + 1}")
plt.xlabel("x coordinate (μm)")
plt.ylabel(r"energy density of far-field electric fields, |E$_z$|$^2$")
plt.title("focusing properties of a binary-grating metasurface lens")
plt.legend(loc="upper right")
plt.tight_layout()
plt.show()
# Out:
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000390053 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.00135708 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00041914 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.03,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.00286388 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000455856 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.0012641 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000399113 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.0382759,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.00274205 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000592947 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.00114202 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000387907 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.0465517,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.00269413 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000613928 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.00121093 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00037694 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.0548276,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.00276113 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000302076 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.00120902 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000390053 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.0631034,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.00249505 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000390053 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.00118399 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000415087 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.0713793,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.00247884 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000272036 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.00150704 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000359058 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.0796552,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.00249887 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000510931 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.00128293 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000397921 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.087931,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.00273108 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000535965 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.00135493 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000406027 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.0962069,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.00249887 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000533819 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.00479102 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000375032 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.104483,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.00250602 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000494003 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.00126195 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000441074 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.112759,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.00258207 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00045085 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.00127816 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000358105 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.121034,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.00264502 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00043416 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.0016911 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00039196 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.12931,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.0027709 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000854969 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.0019331 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000406981 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.137586,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.00447989 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000635147 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.00166106 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000394106 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.145862,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.003968 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000669956 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.00172496 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000401974 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.154138,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.00418806 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000370026 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.00164485 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00039196 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.162414,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.00270391 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000779152 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.00215387 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000406027 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.17069,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.00531602 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000329018 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.00204992 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000478983 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.178966,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.00315595 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000432968 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.0022099 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000447989 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.187241,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.00300694 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000900984 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.00209999 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000402927 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.195517,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.00342894 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000377893 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.002105 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000388861 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.203793,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.00395703 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000559092 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.00206184 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000366926 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.212069,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.00336599 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000687838 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.00124598 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.0004251 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.220345,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.00253892 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000478983 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.00216484 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000401974 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.228621,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.00317097 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00026989 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.00181794 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000383139 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.236897,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.003896 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000422001 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.00153399 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00103807 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.245172,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.00351214 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000917912 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.00158 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000380993 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.253448,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.00459886 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000916004 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.0012989 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000369072 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.261724,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.00321698 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000591993 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
# time for set_epsilon = 0.00144219 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=75.0)
# run 0 finished at t = 75.0 (7500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.000381947 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 0.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,0,0)
#           size (1.8,0.27,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
# time for set_epsilon = 0.00476503 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=225.0)
# run 0 finished at t = 225.0 (22500 timesteps)
# MPB solved for frequency_1(2,0,0) = 2 after 7 iters
# Dominant planewave for band 1: (2.000000,-0.000000,0.000000)
# phase-range:, 6.086173
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00139999 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 60.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,-30,0)
#           size (1.8,0.109864,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,-29.7,0)
#           size (1.8,0.123415,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,-29.4,0)
#           size (1.8,0.136671,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,-29.1,0)
#           size (1.8,0.152579,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,-28.8,0)
#           size (1.8,0.169076,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,-28.5,0)
#           size (1.8,0.186752,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,-28.2,0)
#           size (1.8,0.0500621,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,-27.9,0)
#           size (1.8,0.059489,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,-27.6,0)
#           size (1.8,0.0692104,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      ...(+ 192 objects not shown)...
# time for set_epsilon = 0.745263 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=525.0)
# Meep progress: 40.92/525.0 = 7.8% done in 4.0s, 47.3s to go
# on time step 4093 (time=40.93), 0.000977415 s/step
# Meep progress: 82.35000000000001/525.0 = 15.7% done in 8.0s, 43.0s to go
# on time step 8237 (time=82.37), 0.000965394 s/step
# Meep progress: 122.03/525.0 = 23.2% done in 12.0s, 39.6s to go
# on time step 12205 (time=122.05), 0.00100807 s/step
# Meep progress: 163.54/525.0 = 31.2% done in 16.0s, 35.4s to go
# on time step 16357 (time=163.57), 0.000963564 s/step
# Meep progress: 206.08/525.0 = 39.3% done in 20.0s, 31.0s to go
# on time step 20611 (time=206.11), 0.000940399 s/step
# Meep progress: 248.70000000000002/525.0 = 47.4% done in 24.0s, 26.7s to go
# on time step 24873 (time=248.73), 0.000938565 s/step
# Meep progress: 290.87/525.0 = 55.4% done in 28.0s, 22.5s to go
# on time step 29090 (time=290.9), 0.000948619 s/step
# Meep progress: 333.47/525.0 = 63.5% done in 32.0s, 18.4s to go
# on time step 33351 (time=333.51), 0.000938961 s/step
# Meep progress: 376.24/525.0 = 71.7% done in 36.0s, 14.2s to go
# on time step 37629 (time=376.29), 0.000935168 s/step
# Meep progress: 418.45/525.0 = 79.7% done in 40.0s, 10.2s to go
# on time step 41851 (time=418.51), 0.000947549 s/step
# Meep progress: 461.05/525.0 = 87.8% done in 44.0s, 6.1s to go
# on time step 46112 (time=461.12), 0.000938987 s/step
# Meep progress: 503.63/525.0 = 95.9% done in 48.0s, 2.0s to go
# on time step 50370 (time=503.7), 0.00093952 s/step
# run 0 finished at t = 525.0 (52500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00068903 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 120.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,-60,0)
#           size (1.8,0.09101,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,-59.7,0)
#           size (1.8,0.115166,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,-59.4,0)
#           size (1.8,0.141974,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,-59.1,0)
#           size (1.8,0.174379,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,-58.8,0)
#           size (1.8,0.0533026,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,-58.5,0)
#           size (1.8,0.0730401,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,-58.2,0)
#           size (1.8,0.0933667,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,-57.9,0)
#           size (1.8,0.117523,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,-57.6,0)
#           size (1.8,0.143741,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      ...(+ 392 objects not shown)...
# time for set_epsilon = 1.5553 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=525.0)
# Meep progress: 17.42/525.0 = 3.3% done in 4.0s, 116.6s to go
# on time step 1743 (time=17.43), 0.00229611 s/step
# Meep progress: 35.63/525.0 = 6.8% done in 8.0s, 109.9s to go
# on time step 3564 (time=35.64), 0.00219667 s/step
# Meep progress: 54.32/525.0 = 10.3% done in 12.0s, 104.0s to go
# on time step 5433 (time=54.33), 0.00214088 s/step
# Meep progress: 72.87/525.0 = 13.9% done in 16.0s, 99.3s to go
# on time step 7288 (time=72.88), 0.00215672 s/step
# Meep progress: 89.41/525.0 = 17.0% done in 20.0s, 97.5s to go
# on time step 8942 (time=89.42), 0.00241882 s/step
# Meep progress: 106.03/525.0 = 20.2% done in 24.0s, 94.9s to go
# on time step 10604 (time=106.04), 0.00240675 s/step
# Meep progress: 122.87/525.0 = 23.4% done in 28.0s, 91.7s to go
# on time step 12288 (time=122.88), 0.00237538 s/step
# Meep progress: 140.06/525.0 = 26.7% done in 32.0s, 88.0s to go
# on time step 14007 (time=140.07), 0.00232727 s/step
# Meep progress: 156.91/525.0 = 29.9% done in 36.0s, 84.5s to go
# on time step 15693 (time=156.93), 0.00237371 s/step
# Meep progress: 173.91/525.0 = 33.1% done in 40.0s, 80.8s to go
# on time step 17394 (time=173.94), 0.00235289 s/step
# Meep progress: 192.02/525.0 = 36.6% done in 44.0s, 76.3s to go
# on time step 19205 (time=192.05), 0.00220935 s/step
# Meep progress: 209.41/525.0 = 39.9% done in 48.0s, 72.4s to go
# on time step 20944 (time=209.44), 0.00230106 s/step
# Meep progress: 227.11/525.0 = 43.3% done in 52.0s, 68.2s to go
# on time step 22715 (time=227.15), 0.00225963 s/step
# Meep progress: 244.95000000000002/525.0 = 46.7% done in 56.0s, 64.0s to go
# on time step 24499 (time=244.99), 0.00224283 s/step
# Meep progress: 263.5/525.0 = 50.2% done in 60.0s, 59.6s to go
# on time step 26354 (time=263.54), 0.00215709 s/step
# Meep progress: 282.06/525.0 = 53.7% done in 64.0s, 55.1s to go
# on time step 28211 (time=282.11), 0.00215515 s/step
# Meep progress: 300.09000000000003/525.0 = 57.2% done in 68.0s, 51.0s to go
# on time step 30014 (time=300.14), 0.00221912 s/step
# Meep progress: 318.52/525.0 = 60.7% done in 72.0s, 46.7s to go
# on time step 31858 (time=318.58), 0.00217004 s/step
# Meep progress: 336.96/525.0 = 64.2% done in 76.0s, 42.4s to go
# on time step 33702 (time=337.02), 0.00216987 s/step
# Meep progress: 355.35/525.0 = 67.7% done in 80.0s, 38.2s to go
# on time step 35541 (time=355.41), 0.00217619 s/step
# Meep progress: 373.92/525.0 = 71.2% done in 84.0s, 33.9s to go
# on time step 37398 (time=373.98), 0.00215429 s/step
# Meep progress: 392.28000000000003/525.0 = 74.7% done in 88.0s, 29.8s to go
# on time step 39234 (time=392.34), 0.00217902 s/step
# Meep progress: 410.72/525.0 = 78.2% done in 92.0s, 25.6s to go
# on time step 41078 (time=410.78), 0.00216995 s/step
# Meep progress: 424.78000000000003/525.0 = 80.9% done in 96.0s, 22.7s to go
# on time step 42482 (time=424.82), 0.00285027 s/step
# Meep progress: 439.41/525.0 = 83.7% done in 100.0s, 19.5s to go
# on time step 43946 (time=439.46), 0.00273369 s/step
# Meep progress: 454.93/525.0 = 86.7% done in 104.0s, 16.0s to go
# on time step 45502 (time=455.02), 0.00257207 s/step
# Meep progress: 469.54/525.0 = 89.4% done in 108.0s, 12.8s to go
# on time step 46963 (time=469.63), 0.00273803 s/step
# Meep progress: 487.57/525.0 = 92.9% done in 112.0s, 8.6s to go
# on time step 48766 (time=487.66), 0.00221891 s/step
# Meep progress: 506.19/525.0 = 96.4% done in 116.0s, 4.3s to go
# on time step 50629 (time=506.29), 0.00214781 s/step
# Meep progress: 524.88/525.0 = 100.0% done in 120.0s, 0.0s to go
# on time step 52498 (time=524.98), 0.00214061 s/step
# run 0 finished at t = 525.0 (52500 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00143313 s
# Working in 2D dimensions.
# Computational cell is 7.8 x 240.3 x 0 with resolution 50
#      block, center = (-2.4,0,0)
#           size (3,1e+20,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,-120,0)
#           size (1.8,0.109569,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,-119.7,0)
#           size (1.8,0.161122,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,-119.4,0)
#           size (1.8,0.0609619,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,-119.1,0)
#           size (1.8,0.0983747,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,-118.8,0)
#           size (1.8,0.145804,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,-118.5,0)
#           size (1.8,0.0518297,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,-118.2,0)
#           size (1.8,0.0883587,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,-117.9,0)
#           size (1.8,0.132253,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      block, center = (1.11022e-16,-117.6,0)
#           size (1.8,0.190581,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.25,2.25,2.25)
#      ...(+ 792 objects not shown)...
# time for set_epsilon = 3.24049 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=525.0)
# Meep progress: 9.05/525.0 = 1.7% done in 4.0s, 228.2s to go
# on time step 905 (time=9.05), 0.00442019 s/step
# Meep progress: 18.21/525.0 = 3.5% done in 8.0s, 222.8s to go
# on time step 1821 (time=18.21), 0.00436818 s/step
# Meep progress: 26.580000000000002/525.0 = 5.1% done in 12.0s, 225.2s to go
# on time step 2658 (time=26.58), 0.00478093 s/step
# Meep progress: 35.35/525.0 = 6.7% done in 16.0s, 221.7s to go
# on time step 3536 (time=35.36), 0.00456023 s/step
# Meep progress: 44.32/525.0 = 8.4% done in 20.0s, 217.0s to go
# on time step 4433 (time=44.33), 0.00446345 s/step
# Meep progress: 53.45/525.0 = 10.2% done in 24.0s, 211.9s to go
# on time step 5346 (time=53.46), 0.00438374 s/step
# Meep progress: 62.690000000000005/525.0 = 11.9% done in 28.0s, 206.6s to go
# on time step 6270 (time=62.7), 0.00433315 s/step
# Meep progress: 71.95/525.0 = 13.7% done in 32.0s, 201.6s to go
# on time step 7196 (time=71.96), 0.00432125 s/step
# Meep progress: 81.21000000000001/525.0 = 15.5% done in 36.0s, 196.9s to go
# on time step 8122 (time=81.22), 0.0043227 s/step
# Meep progress: 90.35000000000001/525.0 = 17.2% done in 40.0s, 192.6s to go
# on time step 9036 (time=90.36), 0.00438029 s/step
# Meep progress: 99.62/525.0 = 19.0% done in 44.0s, 188.0s to go
# on time step 9963 (time=99.63), 0.0043181 s/step
# Meep progress: 108.86/525.0 = 20.7% done in 48.0s, 183.6s to go
# on time step 10888 (time=108.88), 0.004329 s/step
# Meep progress: 118.11/525.0 = 22.5% done in 52.0s, 179.3s to go
# on time step 11813 (time=118.13), 0.0043262 s/step
# Meep progress: 127.36/525.0 = 24.3% done in 56.0s, 174.9s to go
# on time step 12738 (time=127.38), 0.00432521 s/step
# Meep progress: 136.63/525.0 = 26.0% done in 60.0s, 170.7s to go
# on time step 13665 (time=136.65), 0.00431729 s/step
# Meep progress: 145.76/525.0 = 27.8% done in 64.0s, 166.6s to go
# on time step 14579 (time=145.79), 0.0043809 s/step
# Meep progress: 155.08/525.0 = 29.5% done in 68.0s, 162.3s to go
# on time step 15511 (time=155.11), 0.00429376 s/step
# Meep progress: 164.37/525.0 = 31.3% done in 72.0s, 158.1s to go
# on time step 16440 (time=164.4), 0.00430884 s/step
# Meep progress: 173.17000000000002/525.0 = 33.0% done in 76.0s, 154.5s to go
# on time step 17320 (time=173.2), 0.0045493 s/step
# Meep progress: 182.28/525.0 = 34.7% done in 80.0s, 150.5s to go
# on time step 18231 (time=182.31), 0.00439549 s/step
# Meep progress: 191.44/525.0 = 36.5% done in 84.1s, 146.5s to go
# on time step 19147 (time=191.47), 0.0043697 s/step
# Meep progress: 200.37/525.0 = 38.2% done in 88.1s, 142.7s to go
# on time step 20041 (time=200.41), 0.00447904 s/step
# Meep progress: 208.1/525.0 = 39.6% done in 92.1s, 140.2s to go
# on time step 20814 (time=208.14), 0.00517729 s/step
# Meep progress: 217.05/525.0 = 41.3% done in 96.1s, 136.3s to go
# on time step 21710 (time=217.1), 0.00446769 s/step
# Meep progress: 226.11/525.0 = 43.1% done in 100.1s, 132.3s to go
# on time step 22616 (time=226.16), 0.0044186 s/step
# Meep progress: 234.9/525.0 = 44.7% done in 104.1s, 128.5s to go
# on time step 23495 (time=234.95), 0.00455423 s/step
# Meep progress: 243.76/525.0 = 46.4% done in 108.1s, 124.7s to go
# on time step 24381 (time=243.81), 0.00451787 s/step
# Meep progress: 252.85/525.0 = 48.2% done in 112.1s, 120.6s to go
# on time step 25290 (time=252.9), 0.00440189 s/step
# Meep progress: 261.86/525.0 = 49.9% done in 116.1s, 116.6s to go
# on time step 26191 (time=261.91), 0.00444282 s/step
# Meep progress: 270.69/525.0 = 51.6% done in 120.1s, 112.8s to go
# on time step 27074 (time=270.74), 0.00453322 s/step
# Meep progress: 279.67/525.0 = 53.3% done in 124.1s, 108.8s to go
# on time step 27972 (time=279.72), 0.00445665 s/step
# Meep progress: 288.7/525.0 = 55.0% done in 128.1s, 104.8s to go
# on time step 28875 (time=288.75), 0.0044332 s/step
# Meep progress: 297.8/525.0 = 56.7% done in 132.1s, 100.8s to go
# on time step 29786 (time=297.86), 0.00439481 s/step
# Meep progress: 306.69/525.0 = 58.4% done in 136.1s, 96.9s to go
# on time step 30675 (time=306.75), 0.0045003 s/step
# Meep progress: 315.65000000000003/525.0 = 60.1% done in 140.1s, 92.9s to go
# on time step 31571 (time=315.71), 0.00446945 s/step
# Meep progress: 324.5/525.0 = 61.8% done in 144.1s, 89.0s to go
# on time step 32457 (time=324.57), 0.00451806 s/step
# Meep progress: 333.22/525.0 = 63.5% done in 148.1s, 85.2s to go
# on time step 33329 (time=333.29), 0.00458989 s/step
# Meep progress: 342.18/525.0 = 65.2% done in 152.1s, 81.3s to go
# on time step 34225 (time=342.25), 0.00446429 s/step
# Meep progress: 351.08/525.0 = 66.9% done in 156.1s, 77.3s to go
# on time step 35115 (time=351.15), 0.00449623 s/step
# Meep progress: 358.7/525.0 = 68.3% done in 160.1s, 74.2s to go
# on time step 35876 (time=358.76), 0.00525674 s/step
# Meep progress: 366.98/525.0 = 69.9% done in 164.1s, 70.7s to go
# on time step 36704 (time=367.04), 0.00483497 s/step
# Meep progress: 375.48/525.0 = 71.5% done in 168.1s, 66.9s to go
# on time step 37555 (time=375.55), 0.00470337 s/step
# Meep progress: 384.1/525.0 = 73.2% done in 172.1s, 63.1s to go
# on time step 38417 (time=384.17), 0.00464362 s/step
# Meep progress: 392.85/525.0 = 74.8% done in 176.1s, 59.2s to go
# on time step 39292 (time=392.92), 0.0045738 s/step
# Meep progress: 401.24/525.0 = 76.4% done in 180.1s, 55.6s to go
# on time step 40131 (time=401.31), 0.00476994 s/step
# Meep progress: 410.08/525.0 = 78.1% done in 184.1s, 51.6s to go
# on time step 41015 (time=410.15), 0.0045283 s/step
# Meep progress: 418.37/525.0 = 79.7% done in 188.1s, 47.9s to go
# on time step 41845 (time=418.45), 0.00482402 s/step
# Meep progress: 427.0/525.0 = 81.3% done in 192.1s, 44.1s to go
# on time step 42709 (time=427.09), 0.00463289 s/step
# Meep progress: 435.51/525.0 = 83.0% done in 196.1s, 40.3s to go
# on time step 43560 (time=435.6), 0.00470562 s/step
# Meep progress: 444.22/525.0 = 84.6% done in 200.1s, 36.4s to go
# on time step 44431 (time=444.31), 0.00459438 s/step
# Meep progress: 453.06/525.0 = 86.3% done in 204.1s, 32.4s to go
# on time step 45315 (time=453.15), 0.00452744 s/step
# Meep progress: 461.67/525.0 = 87.9% done in 208.1s, 28.5s to go
# on time step 46176 (time=461.76), 0.00464675 s/step
# Meep progress: 470.09000000000003/525.0 = 89.5% done in 212.1s, 24.8s to go
# on time step 47017 (time=470.17), 0.00476013 s/step
# Meep progress: 478.35/525.0 = 91.1% done in 216.1s, 21.1s to go
# on time step 47843 (time=478.43), 0.004846 s/step
# Meep progress: 485.87/525.0 = 92.5% done in 220.1s, 17.7s to go
# on time step 48596 (time=485.96), 0.00531665 s/step
# Meep progress: 493.16/525.0 = 93.9% done in 224.1s, 14.5s to go
# on time step 49324 (time=493.24), 0.00550095 s/step
# Meep progress: 500.90000000000003/525.0 = 95.4% done in 228.1s, 11.0s to go
# on time step 50099 (time=500.99), 0.00516273 s/step
# Meep progress: 508.92/525.0 = 96.9% done in 232.1s, 7.3s to go
# on time step 50901 (time=509.01), 0.00498855 s/step
# Meep progress: 516.9/525.0 = 98.5% done in 236.1s, 3.7s to go
# on time step 51699 (time=516.99), 0.0050154 s/step
# Meep progress: 524.85/525.0 = 100.0% done in 240.1s, 0.1s to go
# on time step 52494 (time=524.94), 0.00503514 s/step
# run 0 finished at t = 525.0 (52500 timesteps)
# get_farfields_array working on point 776 of 1000 (77% done), 0.00515697 s/point
